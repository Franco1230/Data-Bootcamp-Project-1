# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time, json, os, csv, requests

from scipy.stats import linregress

from function.helper import clean_house_data, clean_school_data, clean_crime_data

# Hi Markers, please use your onw API keys to run the script, thank you!
from api_keys import g_key

# Set source file path
house_data_path = "data_source/Melbourne_housing_FULL.csv"
school_data_path = "data_source/dv309_schoollocations2021.csv"
crime_rate_path = "data_source/Data_Tables_LGA_Criminal_Incidents_Year_Ending_March_2021.xlsx"

# Set output file path
suburb_lat_lng = "output_files/suburb_lat_lng.csv"
suburb_lat_lng_and_station_count = "output_files/train_station_df.csv"
house_file = "data_source/cleaned_source_data/house_cleaned.csv"
school_file = "data_source/cleaned_source_data/school_cleaned.csv"
crime_file = "data_source/cleaned_source_data/crime_cleaned.csv"
output_file = "graphs/train_station_vs_house_price.png"

# %%
house_data = pd.read_csv(house_data_path)
house_data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
column_to_int_list = ["Postcode",
                      "Bathroom",
                      "Car",
                      "Landsize",
                      "BuildingArea",
                      "YearBuilt",
                      "Propertycount",
                      "Rooms"]

cleaned_house_data = clean_house_data(house_data, column_to_int_list)

cleaned_house_data.to_csv(house_file, index = False, encoding = "utf-8")

cleaned_house_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 5  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 6  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  \
# 1  3/12/2016       2.5      3067         1    1       202             0
# 2  4/02/2016       2.5      3067         1    0       156            79
# 4  4/03/2017       2.5      3067         2    0       134           150
# 5  4/03/2017       2.5      3067         2    1        94             0
# 6  4/06/2016       2.5      3067         1    2       120           142
#
#    YearBuilt         CouncilArea  Lattitude  Longtitude  \
# 1          0  Yarra City Council   -37.7996    144.9984
# 2       1900  Yarra City Council   -37.8079    144.9934
# 4       1900  Yarra City Council   -37.8093    144.9944
# 5          0  Yarra City Council   -37.7969    144.9969
# 6       2014  Yarra City Council   -37.8072    144.9941
#
#               Regionname  Propertycount
# 1  Northern Metropolitan           4019
# 2  Northern Metropolitan           4019
# 4  Northern Metropolitan           4019
# 5  Northern Metropolitan           4019
# 6  Northern Metropolitan           4019

# %%
school_data = pd.read_csv(school_data_path, encoding = "cp1252")
school_data.head()
# Out:
#   Education_Sector  Entity_Type  SCHOOL_NO  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name           X  \
# 0            3971   03 5183 2412    681   Wellington (S)  146.666601
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.590393
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.475649
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.234722
# 4            3113   03 9844 3537    421   Manningham (C)  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675
#
# [5 rows x 21 columns]

# %%
cleaned_school_data = clean_school_data(school_data)

cleaned_school_data.to_csv(school_file, index = False, encoding = "utf-8")

cleaned_school_data.head()
# Out:
#   Education_Sector  Entity_Type                             School_Name  \
# 0       Government            1                 Alberton Primary School
# 1       Government            1  Allansford and District Primary School
# 2       Government            1                    Avoca Primary School
# 3       Government            1                   Avenel Primary School
# 4       Government            1               Warrandyte Primary School
#
#   School_Type School_Status             Address      Suburb State  Postcode  \
# 0     Primary             O   21 Thomson Street    Alberton   VIC      3971
# 1     Primary             O        Frank Street  Allansford   VIC      3277
# 2     Primary             O  118 Barnett Street       Avoca   VIC      3467
# 3     Primary             O  40 Anderson Street      Avenel   VIC      3664
# 4     Primary             O  5-11 Forbes Street  Warrandyte   VIC      3113
#
#   Full_Phone_No  LGA_ID         LGA_Name         Lng        Lat
# 0  03 5183 2412     681   Wellington (S)  146.666601 -38.617713
# 1  03 5565 1382     673  Warrnambool (C)  142.590393 -38.386281
# 2  03 5465 3176     599     Pyrenees (S)  143.475649 -37.084502
# 3  03 5796 2264     643  Strathbogie (S)  145.234722 -36.901368
# 4  03 9844 3537     421   Manningham (C)  145.213980 -37.742675

# %%
crime_data = pd.read_excel(crime_rate_path, sheet_name = "Table 03")
crime_data.head()
# Out:
#    Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0  2021       March                Alpine      3691         Dederang
# 1  2021       March                Alpine      3691       Glen Creek
# 2  2021       March                Alpine      3691       Gundowring
# 3  2021       March                Alpine      3691       Gundowring
# 4  2021       March                Alpine      3691  Kergunyah South
#
#                     Offence Division               Offence Subdivision  \
# 0        A Crimes against the person  A20 Assault and related offences
# 1                    C Drug offences       C30 Drug use and possession
# 2                    C Drug offences  C10 Drug dealing and trafficking
# 3      E Justice procedures offences            E10 Justice procedures
# 4  B Property and deception offences                         B40 Theft
#
#                Offence Subgroup  Incidents Recorded
# 0       A211 FV Serious assault                   1
# 1           C32 Drug possession                   1
# 2          C12 Drug trafficking                   1
# 3  E13 Resist or hinder officer                   1
# 4               B49 Other theft                   1

# %%
cleaned_crime_data = clean_crime_data(crime_data)

cleaned_crime_data.to_csv(crime_file, index = False, encoding = "utf-8")

cleaned_crime_data.head()
# Out:
#    Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0  2018       March                Alpine      3691         Dederang
# 1  2018       March                Alpine      3691         Dederang
# 2  2018       March                Alpine      3691         Dederang
# 3  2018       March                Alpine      3691         Dederang
# 4  2018       March                Alpine      3691       Glen Creek
#
#                        Offence Division                  Offence Subdivision  \
# 0           A Crimes against the person     A20 Assault and related offences
# 1           A Crimes against the person     A20 Assault and related offences
# 2           A Crimes against the person      Other crimes against the person
# 3                       C Drug offences     C10 Drug dealing and trafficking
# 4  D Public order and security offences  D10 Weapons and explosives offences
#
#                   Offence Subgroup  Incidents Recorded
# 0           A231 FV Common assault                   1
# 1       A232 Non-FV Common assault                   1
# 2  Other crimes against the person                   1
# 3             C12 Drug trafficking                   1
# 4            D11 Firearms offences                   2

# %%
cleaned_house_data
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB
# ...           ...               ...    ...  ...        ...    ...
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  Bathroom  Car  Landsize  \
# 1             Biggin   3/12/2016       2.5      3067         1    1       202
# 2             Biggin   4/02/2016       2.5      3067         1    0       156
# 4             Biggin   4/03/2017       2.5      3067         2    0       134
# 5             Biggin   4/03/2017       2.5      3067         2    1        94
# 6             Nelson   4/06/2016       2.5      3067         1    2       120
# ...              ...         ...       ...       ...       ...  ...       ...
# 34852            Jas  24/02/2018       6.3      3013         1    3       593
# 34853        Sweeney  24/02/2018       6.3      3013         2    1        98
# 34854            Jas  24/02/2018       6.3      3013         1    2       220
# 34855  hockingstuart  24/02/2018       6.3      3013         0    0         0
# 34856             RW  24/02/2018       6.3      3013         1    0       250
#
#        BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 1                 0          0        Yarra City Council  -37.79960
# 2                79       1900        Yarra City Council  -37.80790
# 4               150       1900        Yarra City Council  -37.80930
# 5                 0          0        Yarra City Council  -37.79690
# 6               142       2014        Yarra City Council  -37.80720
# ...             ...        ...                       ...        ...
# 34852             0          0  Maribyrnong City Council  -37.81053
# 34853           104       2018  Maribyrnong City Council  -37.81551
# 34854           120       2000  Maribyrnong City Council  -37.82286
# 34855             0          0  Maribyrnong City Council    0.00000
# 34856           103       1930  Maribyrnong City Council  -37.81810
#
#        Longtitude             Regionname  Propertycount
# 1       144.99840  Northern Metropolitan           4019
# 2       144.99340  Northern Metropolitan           4019
# 4       144.99440  Northern Metropolitan           4019
# 5       144.99690  Northern Metropolitan           4019
# 6       144.99410  Northern Metropolitan           4019
# ...           ...                    ...            ...
# 34852   144.88467   Western Metropolitan           6543
# 34853   144.88826   Western Metropolitan           6543
# 34854   144.87856   Western Metropolitan           6543
# 34855     0.00000   Western Metropolitan           6543
# 34856   144.89351   Western Metropolitan           6543
#
# [27247 rows x 20 columns]

# %%
suburbs_price_mean = round(cleaned_house_data.groupby("Suburb").mean()["Price"], 0)
suburbs_price_mean_df = pd.DataFrame({"Avg House Price by Suburb": suburbs_price_mean})
suburbs_price_mean_df = suburbs_price_mean_df.reset_index()
suburbs_price_mean_df
# Out:
#            Suburb  Avg House Price by Suburb
# 0      Abbotsford                  1033549.0
# 1      Aberfeldie                  1307193.0
# 2    Airport West                   751364.0
# 3       Albanvale                   536056.0
# 4     Albert Park                  1927651.0
# ..            ...                        ...
# 340     Yallambie                   820861.0
# 341    Yarra Glen                   620000.0
# 342    Yarraville                   991245.0
# 343       croydon                   730000.0
# 344      viewbank                   885000.0
#
# [345 rows x 2 columns]

# %%
# Drop un-needed columns from the original data frame
train_station_df = house_data.loc[:, ["Suburb", ]]
train_station_df["Lat"] = ""
train_station_df["Lng"] = ""
train_station_df["Train Station Count"] = ""
train_station_df = train_station_df.dropna()
train_station_df = train_station_df.drop_duplicates("Suburb")
train_station_df = train_station_df.reset_index(drop = True)

# %%
# Setup Query URL
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

australia = ", melbourne, australia"
for index, suburb in enumerate(train_station_df["Suburb"]):
    fullAddress = suburb + australia
    
    params = {"key": g_key,
              "address": fullAddress}

    responded_json = requests.get(base_url, params).json()

    try:
        location = responded_json["results"][0]["geometry"]["location"]
        lat = location["lat"]
        lng = location["lng"]
        train_station_df.loc[[index], "Lat"] = lat
        train_station_df.loc[[index], "Lng"] = lng
    
    except:
        print(f"Data retrieve failure.")

train_station_df.head()
# Out:
#          Suburb        Lat         Lng Train Station Count
# 0    Abbotsford    -37.803     145.002
# 1  Airport West -37.726234  144.881353
# 2   Albert Park -37.843861  144.951454
# 3    Alphington     -37.78     145.023
# 4        Altona -37.863151  144.812022

# %%
train_station_df.to_csv(suburb_lat_lng, index = False, encoding = "utf-8")

# %%
# Base url for Google Places API - Nearby Search
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Set parameters for the API call
params = {"keyword": "train",
          "type": "train_station",
          "key": g_key,
          "radius": 3000,
          "location": ""}

for index, row in train_station_df.iterrows():

    params["location"] = str(row[1]) + "," + str(row[2])

    response = requests.get(base_url, params).json()
    station_results = response["results"]
    
    station_list = []
    for result in station_results:
        station_list.append(result["name"])

    try:
        train_station_df.loc[[index], "Train Station Count"] = len(station_list)

    except (KeyError, IndexError):
        print((f"No station found for {row['Suburb']} within 3000 meters."))

# %%
train_station_df.to_csv(suburb_lat_lng_and_station_count, index = False, encoding = "utf-8")
train_station_df
# Out:
#             Suburb        Lat         Lng Train Station Count
# 0       Abbotsford    -37.803     145.002                  19
# 1     Airport West -37.726234  144.881353                   1
# 2      Albert Park -37.843861  144.951454                   4
# 3       Alphington     -37.78     145.023                  15
# 4           Altona -37.863151  144.812022                   3
# ..             ...        ...         ...                 ...
# 346    Fawkner Lot -37.707224   144.96693                   5
# 347    Ferny Creek    -37.878     145.335                   2
# 348   Wandin North    -37.769     145.411                   0
# 349       Kalkallo -37.524563  144.955677                   1
# 350  Menzies Creek    -37.931     145.398                   2
#
# [351 rows x 4 columns]

# %%
avg_price_station_df = pd.merge(train_station_df, suburbs_price_mean_df)
x_values = avg_price_station_df["Avg House Price by Suburb"].astype(int)
y_values = avg_price_station_df["Train Station Count"].astype(int)

color = "orange"
(slope, intercept, _, _, _) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values,y_values, linewidths = 1, marker = "o", edgecolors = "black", color = "purple")
plt.plot(x_values,regress_values,color)
plt.annotate(line_eq,(1700000, 1),fontsize = 15,color = color)
plt.title("House Price VS Number of Train Station Around")
plt.xlabel("Avg House Price (Million)")
plt.ylabel("Train Station Count")
plt.tight_layout()
plt.grid(True)
plt.savefig(output_file)
